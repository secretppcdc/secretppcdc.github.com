# %% [markdown]
# ### Hands-on 3:
#
# * Download and preprocess Named Entity Recognition (NER)  corpus (CONLL 2002)
# * Prepare CRF model for NER
# * Run CRF for training and evaluation
#
#
# ## Named Entity Recognition (NER) using CRF
#
# The task of Named Entity Recognition (NER) involves the recognition of :<br>
# * names of persons
# * locations
# * organizations
# * dates
# * ...
#
#
# #### Example
#
# For example, the following sentence is tagged with sub-sequences indicating PER (for persons), LOC (for location) and ORG (for organization):
#
# <br>
#
# Wolff, currently a journalist in Argentina, played with Del Bosque in the final years of the seventies in Real Madrid.
#
# <br>
#
#
# _______________
#
# <b>[PER Wolff ] </b> , currently a journalist in <b> [LOC Argentina ] </b> , played with <b> [PER Del Bosque ] </b> in the final years  of the seventies in <b> [ORG Real Madrid ] </b> .
#
# _______________
#
# <br>
#
# ### NER - Sub Task Involved :
#
# NER involves 2 sub-tasks: <br>
#
# * identifying the boundaries of such expressions (the open and close brackets) and
# * labeling the expressions (with tags such as PER, LOC or ORG). As for the task of chunking, this sequence labeling task is mapped to a classification tag, using a BIO encoding of the data:  <br>
#
# ### BIO Tagging:
#
# The BIO / IOB format (short for inside, outside, beginning) is a common tagging format for tagging tokens in a chunking task in computational linguistics (ex. named-entity recognition).
#
# * The B- prefix before a tag indicates that the tag is the beginning of a chunk
# * An I- prefix before a tag indicates that the tag is inside a chunk.
# * An O tag indicates that a token belongs to no entity / chunk.
#
# The following figure shows how a BIO tagged sentence looks like:
#
#
#
# ```
#     Wolff B-PER
#             , O
#     currently O
#             a O
#    journalist O
#            in O
#     Argentina B-LOC
#             , O
#        played O
#          with O
#           Del B-PER
#        Bosque I-PER
#            in O
#           the O
#         final O
#         years O
#            of O
#           the O
#     seventies O
#            in O
#          Real B-ORG
#        Madrid I-ORG
#             . O
# ```

# %% [markdown]
# ### DataSet
#
# Let’s use CoNLL 2002 data to build a NER system
#
# CoNLL2002 corpus is available in NLTK.

# %%
# download corpus

import nltk
nltk.download('conll2002')

# get training/testing datasets
from nltk.corpus import conll2002
# Out:
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2002.zip.

# %%
# !pip install pyconll
# Out:
# Collecting pyconll
#   Downloading pyconll-2.3.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests>=2.21 in c:\users\administrator\anaconda3\lib\site-packages (from pyconll) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\administrator\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\administrator\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\administrator\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (2.10)
# Installing collected packages: pyconll
# Successfully installed pyconll-2.3.3

# %% [markdown]
# ###Data Preparation

# %%
path = '.\emerging_entities_17-master\emerging_entities_17-master\wnut17train.conll'
f = open (path,"r",encoding = 'utf-8')

# %%
lines = f.read()
len(lines)
# Out:
# 493781

# %%
lines
# Out:
    fileobj = open(file_path, 'r', encoding='utf-8')
    samples = []
    tokens = []
    tags = []

    for content in fileobj:
 
        content = content.strip('\n')

        if content == '' or content == '\t':
            if len(tokens) != 0 :
                samples.append((tokens, tags))
                tokens = []
                tags = []
        else:
            contents = content.split('\t')
            tokens.append(contents[0])
            tags.append(contents[-1])
                
    return samples

path = '.\emerging_entities_17-master\emerging_entities_17-master\wnut17train.conll'
train = read_file(path)

# %% [markdown]
# def get_sents(lines):
#     """
#     Args:
#         lines (Iterable[str]): the lines
#
#     Yields:
#         List[str]: the lines delimited by an empty line
#     """
#     sent = []
#     stripped_lines = (line.strip() for line in lines)
#     for line in stripped_lines:
#         if line == '':
#             yield sent
#             sent = []
#         else:
#             sent.append(line)
#     yield sent

# %%
path = '.\emerging_entities_17-master\emerging_entities_17-master\wnut17train.conll'
train = read_file(path)
#train[4]
path2 = '.\emerging_entities_17-master\emerging_entities_17-master\emerging.test.conll'
test = read_file(path2)
#test[0]
train[3000][0]
# Out:
# ['@trippy_tay',
#  '::',
#  '[',
#  'Mixtape',
#  ']',
#  'Criminal',
#  'Manne',
#  '-',
#  'Trap',
#  'Talk',
#  '::',
#  'Jan',
#  '.',
#  '30th',
#  '!',
#  'http://t.co/2HixTIfmvL',
#  '@LiveMixtapes',
#  '@Trapaholics',
#  '@Criminal_Manne']

# %%
length = len(test)
for i in range(length):
    
    l = len(test[i][1])
    for j in range(l):
        la = test[i][1][j].split(',')[0]
        test[i][1][j]=la
test[7]
# Out:
# (['(',
#   'Source',
#   ':',
#   'ANI',
#   ')',
#   'Visuals',
#   'of',
#   'the',
#   'avalanche',
#   'site',
#   'in',
#   'Gurez',
#   'sector',
#   '.'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-location',
#   'I-location',
#   'O',
#   'B-corporation',
#   'I-location',
#   'O'])

# %%
## Training and testing


train_sents = list(conll2002.iob_sents('esp.train')) ## spain
test_sents = list(conll2002.iob_sents('esp.testb'))

print(train_sents[0])
#each tuple contains token, syntactic tag, ner label
print(train_sents[12])
# Out:
# [('Melbourne', 'NP', 'B-LOC'), ('(', 'Fpa', 'O'), ('Australia', 'NP', 'B-LOC'), (')', 'Fpt', 'O'), (',', 'Fc', 'O'), ('25', 'Z', 'O'), ('may', 'NC', 'O'), ('(', 'Fpa', 'O'), ('EFE', 'NC', 'B-ORG'), (')', 'Fpt', 'O'), ('.', 'Fp', 'O')]
# [('Gómez', 'NC', 'B-PER'), ('de', 'SP', 'I-PER'), ('la', 'DA', 'I-PER'), ('Hera', 'NC', 'I-PER'), ('comentó', 'VMI', 'O'), ('que', 'CS', 'O'), ('los', 'DA', 'O'), ('contenidos', 'AQ', 'O'), ('de', 'SP', 'O'), ('la', 'DA', 'O'), ('publicación', 'NC', 'O'), ('"', 'Fe', 'O'), ('Ciudad', 'NC', 'B-MISC'), ('"', 'Fe', 'O'), ('responden', 'VMI', 'O'), ('al', 'SP', 'O'), ('programa', 'NC', 'O'), ('que', 'PR', 'O'), ('él', 'PP', 'O'), ('encabezó', 'VMI', 'O'), ('como', 'CS', 'O'), ('candidato', 'NC', 'O'), ('en', 'SP', 'O'), ('las', 'DA', 'O'), ('elecciones', 'NC', 'O'), ('municipales', 'AQ', 'O'), ('de', 'SP', 'O'), ('1999', 'Z', 'O'), (',', 'Fc', 'O'), ('en', 'SP', 'O'), ('las', 'DA', 'O'), ('que', 'PR', 'O'), ('IU', 'NC', 'B-ORG'), ('perdió', 'VMI', 'O'), ('su', 'DP', 'O'), ('representación', 'NC', 'O'), ('en', 'SP', 'O'), ('el', 'DA', 'O'), ('Ayuntamiento', 'NC', 'B-ORG'), (',', 'Fc', 'O'), ('y', 'CC', 'O'), ('confió', 'VMI', 'O'), ('en', 'SP', 'O'), ('que', 'CS', 'O'), ('su', 'DP', 'O'), ('difusión', 'NC', 'O'), ('sea', 'VSS', 'O'), ('más', 'RG', 'O'), ('amplia', 'AQ', 'O'), ('una', 'DI', 'O'), ('vez', 'NC', 'O'), ('que', 'PR', 'O'), ('la', 'DA', 'O'), ('coalición', 'NC', 'O'), ('resuelva', 'VMS', 'O'), ('su', 'DP', 'O'), ('crisis', 'NC', 'O'), ('económica', 'AQ', 'O'), ('.', 'Fp', 'O')]

# %%
train_sents[0][0][2]
# Out:
# 'B-LOC'

# %% [markdown]
# ### Features
#
# - word level features
#     - word shape
#     - word suffix
#
# - Current/previous word context
#     - some information from nearby words is used.
#
# - word POS tag
# - label context
#
# This makes a simple baseline, but you certainly can add and remove some features to get (much?) better results - experiment with it.
#
# sklearn-crfsuite (and python-crfsuite) supports several feature formats;
# here we use feature dicts.

# %%
def word2features2(sent, i):
    
    word = sent[0][i]
    #postag = sent[i][1]


    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        #'postag': postag,
        #'postag[:2]': postag[:2],
    }
    
    if i > 0:
        word1 = sent[0][i-1]
        #postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            #'-1:postag': postag1,
            #'-1:postag[:2]': postag1[:2],
        })
    else:
        # Indicate that it is the 'beginning of a document'
        features['BOS'] = True
        
    
    if i < len(sent[0])-1:
        word1 = sent[0][i+1]
        #postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            #'+1:postag': postag1,
            #'+1:postag[:2]': postag1[:2],
        })
    else:
        # Features for words that are not at the end of a document
        features['EOS'] = True

    return features

# %%
word2features2(train[0], 0)
# Out:
# {'bias': 1.0,
#  'word.lower()': '@paulwalk',
#  'word[-3:]': 'alk',
#  'word[-2:]': 'lk',
#  'word.isupper()': False,
#  'word.istitle()': False,
#  'word.isdigit()': False,
#  'BOS': True,
#  '+1:word.lower()': 'it',
#  '+1:word.istitle()': True,
#  '+1:word.isupper()': False}

# %%
# functions of sentence representations for sequence labelling
def word2features(sent, i):
    
    word = sent[i][0]
    postag = sent[i][1]


    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        # Indicate that it is the 'beginning of a document'
        features['BOS'] = True
        
    
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        # Features for words that are not at the end of a document
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
def sent2features2(sent):
    j=len(sent[0])
    return [word2features2(sent, i) for i in range(j)]

# %%
def sent2labels2(sent):
    return sent[1]

# %%
len(train[4][0])
# Out:
# 12

# %%
sent2labels2(train[4])
# Out:
# ['B-person', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
sent2features2(train[4])
# Out:
# [{'bias': 1.0,
#   'word.lower()': '4dbling',
#   'word[-3:]': 'ing',
#   'word[-2:]': 'ng',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'BOS': True,
#   '+1:word.lower()': "'s",
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': "'s",
#   'word[-3:]': "'s",
#   'word[-2:]': "'s",
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '4dbling',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'place',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'place',
#   'word[-3:]': 'ace',
#   'word[-2:]': 'ce',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': "'s",
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'til',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'til',
#   'word[-3:]': 'til',
#   'word[-2:]': 'il',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'place',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'monday',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'monday',
#   'word[-3:]': 'day',
#   'word[-2:]': 'ay',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'til',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': ',',
#   'word[-3:]': ',',
#   'word[-2:]': ',',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'monday',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'party',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'party',
#   'word[-3:]': 'rty',
#   'word[-2:]': 'ty',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'party',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'party',
#   'word[-3:]': 'rty',
#   'word[-2:]': 'ty',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'party',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': 'party',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': 'party',
#   'word[-3:]': 'rty',
#   'word[-2:]': 'ty',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'party',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': '.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': '.',
#   'word[-3:]': '.',
#   'word[-2:]': '.',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'party',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': '&lt;',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': '&lt;',
#   'word[-3:]': 'lt;',
#   'word[-2:]': 't;',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '+1:word.lower()': '3',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False},
#  {'bias': 1.0,
#   'word.lower()': '3',
#   'word[-3:]': '3',
#   'word[-2:]': '3',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': True,
#   '-1:word.lower()': '&lt;',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   'EOS': True}]

# %% [markdown]
# This is what word2features extracts:

# %%
sample_sentence = " ".join([s for s,c,d in train_sents[2]])
sample_sentence
# Out:
# 'El Abogado General del Estado , Daryl Williams , subrayó hoy la necesidad de tomar medidas para proteger al sistema judicial australiano frente a una página de internet que imposibilita el cumplimiento de los principios básicos de la Ley .'

# %%
train_sents[2][:10]
# Out:
# [('El', 'DA', 'O'),
#  ('Abogado', 'NC', 'B-PER'),
#  ('General', 'AQ', 'I-PER'),
#  ('del', 'SP', 'I-PER'),
#  ('Estado', 'NC', 'I-PER'),
#  (',', 'Fc', 'O'),
#  ('Daryl', 'VMI', 'B-PER'),
#  ('Williams', 'NC', 'I-PER'),
#  (',', 'Fc', 'O'),
#  ('subrayó', 'VMI', 'O')]

# %%
word2features(train_sents[2], 1)
# Out:
# {'bias': 1.0,
#  'word.lower()': 'abogado',
#  'word[-3:]': 'ado',
#  'word[-2:]': 'do',
#  'word.isupper()': False,
#  'word.istitle()': True,
#  'word.isdigit()': False,
#  'postag': 'NC',
#  'postag[:2]': 'NC',
#  '-1:word.lower()': 'el',
#  '-1:word.istitle()': True,
#  '-1:word.isupper()': False,
#  '-1:postag': 'DA',
#  '-1:postag[:2]': 'DA',
#  '+1:word.lower()': 'general',
#  '+1:word.istitle()': True,
#  '+1:word.isupper()': False,
#  '+1:postag': 'AQ',
#  '+1:postag[:2]': 'AQ'}

# %%
sent2features(train_sents[2])
# Out:
# [{'bias': 1.0,
#   'word.lower()': 'el',
#   'word[-3:]': 'El',
#   'word[-2:]': 'El',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'DA',
#   'postag[:2]': 'DA',
#   'BOS': True,
#   '+1:word.lower()': 'abogado',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'abogado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'el',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DA',
#   '-1:postag[:2]': 'DA',
#   '+1:word.lower()': 'general',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'AQ',
#   '+1:postag[:2]': 'AQ'},
#  {'bias': 1.0,
#   'word.lower()': 'general',
#   'word[-3:]': 'ral',
#   'word[-2:]': 'al',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'AQ',
#   'postag[:2]': 'AQ',
#   '-1:word.lower()': 'abogado',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'del',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'del',
#   'word[-3:]': 'del',
#   'word[-2:]': 'el',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'general',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'AQ',
#   '-1:postag[:2]': 'AQ',
#   '+1:word.lower()': 'estado',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'estado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'del',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'Fc',
#   '+1:postag[:2]': 'Fc'},
#  {'bias': 1.0,
#   'word.lower()': ',',
#   'word[-3:]': ',',
#   'word[-2:]': ',',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'Fc',
#   'postag[:2]': 'Fc',
#   '-1:word.lower()': 'estado',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'daryl',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'VMI',
#   '+1:postag[:2]': 'VM'},
#  {'bias': 1.0,
#   'word.lower()': 'daryl',
#   'word[-3:]': 'ryl',
#   'word[-2:]': 'yl',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'VMI',
#   'postag[:2]': 'VM',
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'Fc',
#   '-1:postag[:2]': 'Fc',
#   '+1:word.lower()': 'williams',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'williams',
#   'word[-3:]': 'ams',
#   'word[-2:]': 'ms',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'daryl',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'VMI',
#   '-1:postag[:2]': 'VM',
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'Fc',
#   '+1:postag[:2]': 'Fc'},
#  {'bias': 1.0,
#   'word.lower()': ',',
#   'word[-3:]': ',',
#   'word[-2:]': ',',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'Fc',
#   'postag[:2]': 'Fc',
#   '-1:word.lower()': 'williams',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'subrayó',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'VMI',
#   '+1:postag[:2]': 'VM'},
#  {'bias': 1.0,
#   'word.lower()': 'subrayó',
#   'word[-3:]': 'ayó',
#   'word[-2:]': 'yó',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'VMI',
#   'postag[:2]': 'VM',
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'Fc',
#   '-1:postag[:2]': 'Fc',
#   '+1:word.lower()': 'hoy',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'RG',
#   '+1:postag[:2]': 'RG'},
#  {'bias': 1.0,
#   'word.lower()': 'hoy',
#   'word[-3:]': 'hoy',
#   'word[-2:]': 'oy',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'RG',
#   'postag[:2]': 'RG',
#   '-1:word.lower()': 'subrayó',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'VMI',
#   '-1:postag[:2]': 'VM',
#   '+1:word.lower()': 'la',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'DA',
#   '+1:postag[:2]': 'DA'},
#  {'bias': 1.0,
#   'word.lower()': 'la',
#   'word[-3:]': 'la',
#   'word[-2:]': 'la',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'DA',
#   'postag[:2]': 'DA',
#   '-1:word.lower()': 'hoy',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'RG',
#   '-1:postag[:2]': 'RG',
#   '+1:word.lower()': 'necesidad',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'necesidad',
#   'word[-3:]': 'dad',
#   'word[-2:]': 'ad',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'la',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DA',
#   '-1:postag[:2]': 'DA',
#   '+1:word.lower()': 'de',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'necesidad',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'tomar',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'VMN',
#   '+1:postag[:2]': 'VM'},
#  {'bias': 1.0,
#   'word.lower()': 'tomar',
#   'word[-3:]': 'mar',
#   'word[-2:]': 'ar',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'VMN',
#   'postag[:2]': 'VM',
#   '-1:word.lower()': 'de',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'medidas',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'medidas',
#   'word[-3:]': 'das',
#   'word[-2:]': 'as',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'tomar',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'VMN',
#   '-1:postag[:2]': 'VM',
#   '+1:word.lower()': 'para',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'para',
#   'word[-3:]': 'ara',
#   'word[-2:]': 'ra',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'medidas',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'proteger',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'VMN',
#   '+1:postag[:2]': 'VM'},
#  {'bias': 1.0,
#   'word.lower()': 'proteger',
#   'word[-3:]': 'ger',
#   'word[-2:]': 'er',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'VMN',
#   'postag[:2]': 'VM',
#   '-1:word.lower()': 'para',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'al',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'al',
#   'word[-3:]': 'al',
#   'word[-2:]': 'al',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'proteger',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'VMN',
#   '-1:postag[:2]': 'VM',
#   '+1:word.lower()': 'sistema',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'sistema',
#   'word[-3:]': 'ema',
#   'word[-2:]': 'ma',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'al',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'judicial',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'AQ',
#   '+1:postag[:2]': 'AQ'},
#  {'bias': 1.0,
#   'word.lower()': 'judicial',
#   'word[-3:]': 'ial',
#   'word[-2:]': 'al',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'AQ',
#   'postag[:2]': 'AQ',
#   '-1:word.lower()': 'sistema',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'australiano',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'AQ',
#   '+1:postag[:2]': 'AQ'},
#  {'bias': 1.0,
#   'word.lower()': 'australiano',
#   'word[-3:]': 'ano',
#   'word[-2:]': 'no',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'AQ',
#   'postag[:2]': 'AQ',
#   '-1:word.lower()': 'judicial',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'AQ',
#   '-1:postag[:2]': 'AQ',
#   '+1:word.lower()': 'frente',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'RG',
#   '+1:postag[:2]': 'RG'},
#  {'bias': 1.0,
#   'word.lower()': 'frente',
#   'word[-3:]': 'nte',
#   'word[-2:]': 'te',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'RG',
#   'postag[:2]': 'RG',
#   '-1:word.lower()': 'australiano',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'AQ',
#   '-1:postag[:2]': 'AQ',
#   '+1:word.lower()': 'a',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'a',
#   'word[-3:]': 'a',
#   'word[-2:]': 'a',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'frente',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'RG',
#   '-1:postag[:2]': 'RG',
#   '+1:word.lower()': 'una',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'DI',
#   '+1:postag[:2]': 'DI'},
#  {'bias': 1.0,
#   'word.lower()': 'una',
#   'word[-3:]': 'una',
#   'word[-2:]': 'na',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'DI',
#   'postag[:2]': 'DI',
#   '-1:word.lower()': 'a',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'página',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'página',
#   'word[-3:]': 'ina',
#   'word[-2:]': 'na',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'una',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DI',
#   '-1:postag[:2]': 'DI',
#   '+1:word.lower()': 'de',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'página',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'internet',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'internet',
#   'word[-3:]': 'net',
#   'word[-2:]': 'et',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'de',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'que',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'PR',
#   '+1:postag[:2]': 'PR'},
#  {'bias': 1.0,
#   'word.lower()': 'que',
#   'word[-3:]': 'que',
#   'word[-2:]': 'ue',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'PR',
#   'postag[:2]': 'PR',
#   '-1:word.lower()': 'internet',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'imposibilita',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'VMI',
#   '+1:postag[:2]': 'VM'},
#  {'bias': 1.0,
#   'word.lower()': 'imposibilita',
#   'word[-3:]': 'ita',
#   'word[-2:]': 'ta',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'VMI',
#   'postag[:2]': 'VM',
#   '-1:word.lower()': 'que',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'PR',
#   '-1:postag[:2]': 'PR',
#   '+1:word.lower()': 'el',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'DA',
#   '+1:postag[:2]': 'DA'},
#  {'bias': 1.0,
#   'word.lower()': 'el',
#   'word[-3:]': 'el',
#   'word[-2:]': 'el',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'DA',
#   'postag[:2]': 'DA',
#   '-1:word.lower()': 'imposibilita',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'VMI',
#   '-1:postag[:2]': 'VM',
#   '+1:word.lower()': 'cumplimiento',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'cumplimiento',
#   'word[-3:]': 'nto',
#   'word[-2:]': 'to',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'el',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DA',
#   '-1:postag[:2]': 'DA',
#   '+1:word.lower()': 'de',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'cumplimiento',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'los',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'DA',
#   '+1:postag[:2]': 'DA'},
#  {'bias': 1.0,
#   'word.lower()': 'los',
#   'word[-3:]': 'los',
#   'word[-2:]': 'os',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'DA',
#   'postag[:2]': 'DA',
#   '-1:word.lower()': 'de',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'principios',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'principios',
#   'word[-3:]': 'ios',
#   'word[-2:]': 'os',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'los',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DA',
#   '-1:postag[:2]': 'DA',
#   '+1:word.lower()': 'básicos',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'AQ',
#   '+1:postag[:2]': 'AQ'},
#  {'bias': 1.0,
#   'word.lower()': 'básicos',
#   'word[-3:]': 'cos',
#   'word[-2:]': 'os',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'AQ',
#   'postag[:2]': 'AQ',
#   '-1:word.lower()': 'principios',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   '+1:word.lower()': 'de',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'SP',
#   '+1:postag[:2]': 'SP'},
#  {'bias': 1.0,
#   'word.lower()': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'SP',
#   'postag[:2]': 'SP',
#   '-1:word.lower()': 'básicos',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'AQ',
#   '-1:postag[:2]': 'AQ',
#   '+1:word.lower()': 'la',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'DA',
#   '+1:postag[:2]': 'DA'},
#  {'bias': 1.0,
#   'word.lower()': 'la',
#   'word[-3:]': 'la',
#   'word[-2:]': 'la',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'DA',
#   'postag[:2]': 'DA',
#   '-1:word.lower()': 'de',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'SP',
#   '-1:postag[:2]': 'SP',
#   '+1:word.lower()': 'ley',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NC',
#   '+1:postag[:2]': 'NC'},
#  {'bias': 1.0,
#   'word.lower()': 'ley',
#   'word[-3:]': 'Ley',
#   'word[-2:]': 'ey',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'postag': 'NC',
#   'postag[:2]': 'NC',
#   '-1:word.lower()': 'la',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:postag': 'DA',
#   '-1:postag[:2]': 'DA',
#   '+1:word.lower()': '.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'Fp',
#   '+1:postag[:2]': 'Fp'},
#  {'bias': 1.0,
#   'word.lower()': '.',
#   'word[-3:]': '.',
#   'word[-2:]': '.',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'Fp',
#   'postag[:2]': 'Fp',
#   '-1:word.lower()': 'ley',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:postag': 'NC',
#   '-1:postag[:2]': 'NC',
#   'EOS': True}]

# %% [markdown]
# ### Feature Extraction:
#
# Extract features from the training data and testing data

# %%
# sentence representations for sequence labelling
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %%
# sentence representations for sequence labelling
X_train2 = [sent2features2(s) for s in train]
y_train2 = [sent2labels2(s) for s in train]

X_test2 = [sent2features2(s) for s in test]
y_test2 = [sent2labels2(s) for s in test]

# %%
train_sents[0], y_train[0]
# Out:
# ([('Melbourne', 'NP', 'B-LOC'),
#   ('(', 'Fpa', 'O'),
#   ('Australia', 'NP', 'B-LOC'),
#   (')', 'Fpt', 'O'),
#   (',', 'Fc', 'O'),
#   ('25', 'Z', 'O'),
#   ('may', 'NC', 'O'),
#   ('(', 'Fpa', 'O'),
#   ('EFE', 'NC', 'B-ORG'),
#   (')', 'Fpt', 'O'),
#   ('.', 'Fp', 'O')],
#  ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O'])

# %%
X_train2[1], y_train2[1]
# Out:
# ([{'bias': 1.0,
#    'word.lower()': 'from',
#    'word[-3:]': 'rom',
#    'word[-2:]': 'om',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'BOS': True,
#    '+1:word.lower()': 'green',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'green',
#    'word[-3:]': 'een',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'from',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'newsfeed',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'newsfeed',
#    'word[-3:]': 'eed',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'green',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': ':',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': ':',
#    'word[-3:]': ':',
#    'word[-2:]': ':',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'newsfeed',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'ahfa',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True},
#   {'bias': 1.0,
#    'word.lower()': 'ahfa',
#    'word[-3:]': 'HFA',
#    'word[-2:]': 'FA',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': ':',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'extends',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'extends',
#    'word[-3:]': 'nds',
#    'word[-2:]': 'ds',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'ahfa',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '+1:word.lower()': 'deadline',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'deadline',
#    'word[-3:]': 'ine',
#    'word[-2:]': 'ne',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'extends',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'for',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'for',
#    'word[-3:]': 'for',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'deadline',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'sage',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'sage',
#    'word[-3:]': 'age',
#    'word[-2:]': 'ge',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'for',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'award',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'award',
#    'word[-3:]': 'ard',
#    'word[-2:]': 'rd',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'sage',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'award',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'nov',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'nov',
#    'word[-3:]': 'Nov',
#    'word[-2:]': 'ov',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': 'nov',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': '5',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': '5',
#    'word[-3:]': '5',
#    'word[-2:]': '5',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '+1:word.lower()': 'http://tinyurl.com/24agj38',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False},
#   {'bias': 1.0,
#    'word.lower()': 'http://tinyurl.com/24agj38',
#    'word[-3:]': 'j38',
#    'word[-2:]': '38',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    '-1:word.lower()': '5',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    'EOS': True}],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-group',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'])

# %% [markdown]
# ### Training
# Here we are using L-BFGS training algorithm (it is default) with Elastic Net (L1 + L2) regularization.

# %%
# train CRF model
# !pip install sklearn_crfsuite
import sklearn_crfsuite
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=1000,
    all_possible_transitions=True
)
# Out:
# Requirement already satisfied: sklearn_crfsuite in c:\users\administrator\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: tqdm>=2.0 in c:\users\administrator\anaconda3\lib\site-packages (from sklearn_crfsuite) (4.47.0)
# Requirement already satisfied: tabulate in c:\users\administrator\anaconda3\lib\site-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: six in c:\users\administrator\anaconda3\lib\site-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\administrator\anaconda3\lib\site-packages (from sklearn_crfsuite) (0.9.7)

# %%
crf
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
crf.fit(X_train, y_train)

# training model parameters
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
 y_train2[4]
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O']

# %%
crf.fit(X_train2, y_train2)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=1000)

# %% [markdown]
# ### Evaluation
# There is much more O entities in data set, but we’re more interested in other entities. To account for this we’ll use averaged F1 score computed for all labels except for O. sklearn-crfsuite.metrics package provides some useful metrics for sequence classification task, including this one.

# %%
# get label set
labels = list(crf.classes_)
labels.remove('O')
print(labels)
# Out:
# ['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']

# %%
labels2 = ['B-location',
 'B-product',
 'O',
 'I-corporation',
 'I-creative-work',
 'I-person',
 'B-person',
 'B-corporation',
 'I-group',
 'I-product',
 'B-creative-work',
 'B-group',
 'I-location']

# %%
# evaluate CRF model
from sklearn_crfsuite import metrics

y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
# Out:
# 0.7964686316443963

# %%
# evaluate CRF model
from sklearn_crfsuite import metrics

y_pred2 = crf.predict(X_test2)
metrics.flat_f1_score(y_test2, y_pred2, average='weighted', labels=labels2)
# Out:
# 0.9163362748991393

# %%
y_pred2[8]
# Out:
# ['O', 'O', 'O', 'O', 'O']

# %% [markdown]
# ### Inspect per-class results in more detail:

# %%
# group B and I results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass labels=['B-LOC', 'I-LOC', 'B-MISC', 'I-MISC', 'B-ORG', 'I-ORG', 'B-PER', 'I-PER'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
#               precision    recall  f1-score   support
#
#        B-LOC      0.810     0.784     0.797      1084
#        I-LOC      0.690     0.637     0.662       325
#       B-MISC      0.731     0.569     0.640       339
#       I-MISC      0.699     0.589     0.639       557
#        B-ORG      0.807     0.832     0.820      1400
#        I-ORG      0.852     0.786     0.818      1104
#        B-PER      0.850     0.884     0.867       735
#        I-PER      0.893     0.943     0.917       634
#
#    micro avg      0.813     0.787     0.799      6178
#    macro avg      0.791     0.753     0.770      6178
# weighted avg      0.809     0.787     0.796      6178
